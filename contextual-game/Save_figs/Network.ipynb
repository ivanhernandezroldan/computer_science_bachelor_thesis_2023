# %%
import networkx as nx
import matplotlib.pyplot as plt

edges = [
    (1,2), (1,3), (2,1), (2,6), (3,1), (3,4), (3,12), (4,3), (4,5), (4,11),
    (5,4), (5,6), (5,9), (6,2), (6,5), (6,8), (7,8), (7,18), (8,6), (8,7),
    (8,9), (8,16), (9,5), (9,8), (9,10), (10,9), (10,11), (10,15), (10,16),
    (10,17), (11,4), (11,10), (11,12), (11,14), (12,3), (12,11), (12,13),
    (13,12), (13,24), (14,11), (14,15), (14,23), (15,10), (15,14), (15,19),
    (15,22), (16,8), (16,10), (16,17), (16,18), (17,10), (17,16), (17,19),
    (18,7), (18,16), (18,20), (19,15), (19,17), (19,20), (20,18), (20,19),
    (20,21), (20,22), (21,20), (21,22), (21,24), (22,15), (22,20), (22,21),
    (22,23), (23,14), (23,22), (23,24), (24,13), (24,21), (24,23)
]

positions = {
    1: (50000, 510000),
    2: (320000, 510000),
    3: (50000, 440000),
    4: (130000, 440000),
    5: (220000, 440000),
    6: (320000, 440000),
    7: (420000, 380000),
    8: (320000, 380000),
    9: (220000, 380000),
    10: (220000, 320000),
    11: (130000, 320000),
    12: (50000, 320000),
    13: (50000, 50000),
    14: (130000, 190000),
    15: (220000, 190000),
    16: (320000, 320000),
    17: (320000, 260000),
    18: (420000, 320000),
    19: (320000, 190000),
    20: (320000, 50000),
    21: (220000, 50000),
    22: (220000, 130000),
    23: (130000, 130000),
    24: (130000, 50000),
}

G = nx.DiGraph()
G.add_edges_from(edges)

nx.draw(G, positions, with_labels=True, node_color='lightblue', node_size=1200, edge_color='gray', width=2.0, arrows=False)
plt.show()
